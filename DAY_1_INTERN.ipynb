# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshj10x/Codeboosters-Internship-2026/blob/main/DAY_1_INTERN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("library imported successfully")

df = pd.read_csv("student_performance.csv")

df.columns.tolist()
# Out:
# library imported successfully
# ['student_id',
#  'name',
#  'age',
#  'gender',
#  'department',
#  'semester',
#  'math_score',
#  'science_score',
#  'english_score',
#  'programming_score',
#  'attendance_percentage',
#  'city',
#  'admission_year']

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
df.shape
# Out:
# (30, 13)

# %%
df.dtypes
# Out:
# student_id                int64
# name                     object
# age                       int64
# gender                   object
# department               object
# semester                  int64
# math_score                int64
# science_score             int64
# english_score             int64
# programming_score         int64
# attendance_percentage     int64
# city                     object
# admission_year            int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               0
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df['city']
# Out:
# 0                 Mumbai
# 1              Ahmedabad
# 2                  Delhi
# 3              Hyderabad
# 4                  Kochi
# 5                   Pune
# 6              Bangalore
# 7                Lucknow
# 8               Varanasi
# 9                Kolkata
# 10               Chennai
# 11                Jaipur
# 12                Mysore
# 13              Thrissur
# 14                Bhopal
# 15                  Agra
# 16                 Patna
# 17                Nagpur
# 18              Dehradun
# 19            Chandigarh
# 20    Thiruvananthapuram
# 21                 Surat
# 22             Allahabad
# 23                Kanpur
# 24               Kolkata
# 25                 Kochi
# 26               Lucknow
# 27    Thiruvananthapuram
# 28                Indore
# 29                  Agra
# Name: city, dtype: object

# %%
df["city"].value_counts()
# Out:
# city
# Kochi                 2
# Lucknow               2
# Thiruvananthapuram    2
# Agra                  2
# Kolkata               2
# Hyderabad             1
# Mumbai                1
# Delhi                 1
# Ahmedabad             1
# Varanasi              1
# Bangalore             1
# Pune                  1
# Jaipur                1
# Mysore                1
# Thrissur              1
# Bhopal                1
# Chennai               1
# Patna                 1
# Nagpur                1
# Dehradun              1
# Chandigarh            1
# Surat                 1
# Allahabad             1
# Kanpur                1
# Indore                1
# Name: count, dtype: int64

# %%
stu = df[df["city"] == "Kochi"]
print(f"number of student from Kochi: {len(stu)}")
# Out:
# number of student from Kochi: 2

# %%
print(stu[['admission_year', 'age','city']])
# Out:
#     admission_year  age   city
# 4             2023   19  Kochi
# 25            2023   20  Kochi

# %%
a=df[df['age']>20]
print(a['name'])
# Out:
# 6       Kiran Kumar
# 12       Suresh Rao
# 16     Manoj Pandey
# 22     Sanjay Dubey
# 26    Gaurav Shukla
# Name: name, dtype: object

# %%
high=df[df['admission_year']>90]
print(high)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
df['total_score'] = df['math_score'] + df['science_score'] + df['english_score'] + df['programming_score']
avg=df.groupby('department')['total_score'].mean().round(2)
print(avg)
# Out:
# department
# Civil               235.80
# Computer Science    340.15
# Electronics         277.50
# Mechanical          267.33
# Name: total_score, dtype: float64

# %%
s=df.sort_values(by='total_score' , ascending=False)
s.head()
# Out:
#     student_id            name  age  gender        department  semester  \
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 21        1022     Tanvi Mehta   19  Female  Computer Science         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 9           95             89             90                 97
# 21          93             90             88                 96
# 29          91             93             87                 94
# 4           92             88             81                 95
# 7           88             91             84                 93
#
#     attendance_percentage     city  admission_year  total_score
# 9                      98  Kolkata            2023          371
# ...
